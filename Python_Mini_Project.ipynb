# %%
name=input("Enter cx name:")
age=int(input("Enter cx age:"))
# Out:
# Enter cx name:Alex
# Enter cx age:23

# %%
min_balance=500
initial_amount=int(input("Enter the amount for account activation"))
if initial_amount>=min_balance:
  account_activate=True
  print("Account activated")
  balance=initial_amount
else:
  print(f"Minimum balance required for acount activation {min_balance}")
# Out:
# Enter the amount for account activation500
# Account activated

# %%
deposit=int(input("Enter the amount deposited"))
amount=deposit+balance
print(f"The total balance is",{amount})
# Out:
# Enter the amount deposited1000
# The total balance is {1500}

# %%
withdrawl=int(input("Enter the amount to be withdrawl"))
transaction_charges=50
if withdrawl+transaction_charges<=amount:
  print("Withdrawl successful")
  total_balance=amount-withdrawl-transaction_charges
else:
  print("Insufficiant balance")
# Out:
# Enter the amount to be withdrawl1000
# Withdrawl successful

# %%
print(name)
print(age)
print(balance)
print(account_activate)
# Out:
# Alex
# 23
# 500
# True
